# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import os
import pickle

# %%
with open("data.txt", "r", encoding='utf-8') as f:
    text_data = f.read()

# %%
text_data
# Out:
# "my name is tanjina proma. I work in IUB.\nHi, I'm Tanjina Proma, a passionate Machine Learning Engineer.\nI am enhancing my knowledge with the latest development in the field of Machine Learning and Data Science.\nI have worked for more than four years, and I have a record of successfully implementing Computer Vision and Image Processing based pipelines with practical expertise using MLOps, deep learning & machine learning. \nI am interested in enabling machine to understand sequence of information and act accordingly to make significant progress towards true artificial intelligence.\n\nI am currently working in IUB as a Lecturer. I am teaching CIS101 and CSE100 courses.\nSince 2024 i am working there. I have also started Masters over there. MSc degree takes 2 years to complete. I am hoping  to finish it before required timeframe.\nI am pursuing MSc in CSC. Along with that i am also doing research work.\n "

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts([text_data])

# %%
tokenizer

# %%
tokenizer.texts_to_sequences([text_data ])
# Out:
# [[13,
#   24,
#   25,
#   14,
#   15,
#   2,
#   16,
#   4,
#   17,
#   26,
#   27,
#   14,
#   15,
#   9,
#   28,
#   6,
#   7,
#   29,
#   2,
#   3,
#   30,
#   13,
#   31,
#   10,
#   18,
#   32,
#   33,
#   4,
#   18,
#   34,
#   11,
#   6,
#   7,
#   5,
#   35,
#   36,
#   2,
#   12,
#   37,
#   38,
#   39,
#   40,
#   41,
#   19,
#   5,
#   2,
#   12,
#   9,
#   42,
#   11,
#   43,
#   44,
#   45,
#   46,
#   5,
#   47,
#   48,
#   49,
#   50,
#   10,
#   51,
#   52,
#   53,
#   54,
#   55,
#   7,
#   6,
#   7,
#   2,
#   3,
#   56,
#   4,
#   57,
#   6,
#   8,
#   58,
#   59,
#   11,
#   60,
#   5,
#   61,
#   62,
#   8,
#   63,
#   64,
#   65,
#   66,
#   67,
#   68,
#   69,
#   2,
#   3,
#   70,
#   20,
#   4,
#   17,
#   71,
#   9,
#   72,
#   2,
#   3,
#   73,
#   74,
#   5,
#   75,
#   76,
#   77,
#   78,
#   2,
#   3,
#   20,
#   21,
#   2,
#   12,
#   22,
#   79,
#   80,
#   81,
#   21,
#   23,
#   82,
#   83,
#   84,
#   19,
#   8,
#   85,
#   2,
#   3,
#   86,
#   8,
#   87,
#   88,
#   89,
#   90,
#   91,
#   2,
#   3,
#   92,
#   23,
#   4,
#   93,
#   94,
#   10,
#   95,
#   2,
#   3,
#   22,
#   96,
#   97,
#   16]]
