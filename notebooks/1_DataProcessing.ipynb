# %%
import nltk

# %%
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\Tanjina\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\Tanjina\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\Tanjina\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Tanjina\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\Tanjina\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# ...

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
texts()
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
text = "I am Tanjina Proma. I am a Lecturer in IUB CSE Department. I am teaching CIS101 Lab course"

# %%
word_tokenize(text)
# Out:
# ['I',
#  'am',
#  'Tanjina',
#  'Proma',
#  '.',
#  'I',
#  'am',
#  'a',
#  'Lecturer',
#  'in',
#  'IUB',
#  'CSE',
#  'Department',
#  '.',
#  'I',
#  'am',
#  'teaching',
#  'CIS101',
#  'Lab',
#  'course']

# %%
sent_tokenize(text)
# Out:
# ['I am Tanjina Proma.',
#  'I am a Lecturer in IUB CSE Department.',
#  'I am teaching CIS101 Lab course']

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
len(stopwords.words('english'))
# Out:
# 198

# %%
text
# Out:
# 'I am Tanjina Proma. I am a Lecturer in IUB CSE Department. I am teaching CIS101 Lab course'

# %%
text.lower()
# Out:
# 'i am tanjina proma. i am a lecturer in iub cse department. i am teaching cis101 lab course'

# %%
[i for i in word_tokenize(text.lower()) if i not in stopwords.words('english')]
# Out:
# ['tanjina',
#  'proma',
#  '.',
#  'lecturer',
#  'iub',
#  'cse',
#  'department',
#  '.',
#  'teaching',
#  'cis101',
#  'lab',
#  'course']

# %%
from nltk.stem import PorterStemmer

# %%
stemer = PorterStemmer()
for i in word_tokenize(text):
    print(f"{i} --> {stemer.stem(i)}")
# Out:
# I --> i
# am --> am
# Tanjina --> tanjina
# Proma --> proma
# . --> .
# I --> i
# am --> am
# a --> a
# Lecturer --> lectur
# in --> in
# IUB --> iub
# CSE --> cse
# Department --> depart
# . --> .
# I --> i
# am --> am
# teaching --> teach
# CIS101 --> cis101
# Lab --> lab
# course --> cours

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tanjina\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text_token = word_tokenize(text)
text_token
# Out:
# ['I',
#  'am',
#  'Tanjina',
#  'Proma',
#  '.',
#  'I',
#  'am',
#  'a',
#  'Lecturer',
#  'in',
#  'IUB',
#  'CSE',
#  'Department',
#  '.',
#  'I',
#  'am',
#  'teaching',
#  'CIS101',
#  'Lab',
#  'course']

# %%
for i in text_token:
    print(f"{i} --> {WordNetLemmatizer().lemmatize(i)}")
# Out:
# I --> I
# am --> am
# Tanjina --> Tanjina
# Proma --> Proma
# . --> .
# I --> I
# am --> am
# a --> a
# Lecturer --> Lecturer
# in --> in
# IUB --> IUB
# CSE --> CSE
# Department --> Department
# . --> .
# I --> I
# am --> am
# teaching --> teaching
# CIS101 --> CIS101
# Lab --> Lab
# course --> course

# %%
from nltk.stem import LancasterStemmer

# %%
lanc = LancasterStemmer()

# %%
lanc.stem("running")
# Out:
# 'run'

# %%
from nltk.tag import pos_tag

# %%
pos_tag(["Proma", "teaching","proma", "."])
# Out:
# [('Proma', 'NNP'), ('teaching', 'VBG'), ('proma', 'NN'), ('.', '.')]
