# %%
pip install openai
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.1/1.1 MB 4.2 MB/s eta 0:00:01
#    ------------ --------------------------- 0.3/1.1 MB 3.5 MB/s eta 0:00:01
#    ------------------- -------------------- 0.5/1.1 MB 3.6 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.1 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.8 kB 3.8 MB/s eta 0:00:01
# ...

# %%
import openai
openai.api_key = "your API"
openai.completion.create{
    model: "text-davinci-003",
    prompt: "Write a poem about a baby",
    temperature: 0,
    max_tokens: 7
}

# %%
import openai
openai.api_key = "your API"

openai.chat.completions.create({
    model: "gpt-3.5-turbo",
    messages: [
        {"role": "system", "content": "You are an experienced data scientist."},
        {"role": "user", "content": "give me a roadmap to become a data scientist."}
    ],
    temperature: 0.7
})

# %%
# Using requests library
import requests

def generate_completion():
    url = "https://api.openai.com/v1/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer your API"
    }
    payload = {
        messages: [
            {"role": "user", 
            "content": "Give me a temperature in dhaka today"
            }
        ],
        model: "gpt-3.5-turbo",
        temperature: 0.7
        max_tokens: 150
    }
    response = requests.post(url, headers=headers, json=payload)
    return response.json()
